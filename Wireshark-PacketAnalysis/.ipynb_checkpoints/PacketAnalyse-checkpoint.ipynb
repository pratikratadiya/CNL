# %%
import csv

# %%
ip, udp, tcp, arp = 0,0,0,0

# %%
with open('a7.csv') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        if 'ICMPv6' in row:
            ip = ip + 1
            print(*row[1:])
            
print("There are %s IP packets!" % ip)
# Out:
# 0.034725000 fe80::726d:ecff:fe02:a6 ff02::1 ICMPv6 86 Multicast Listener Query
# 0.038085000 fe80::726d:ecff:fe02:a6 ff02::1 ICMPv6 86 Multicast Listener Query
# 0.045955000 fe80::6508:d80c:c8ce:134c ff02::c ICMPv6 86 Multicast Listener Report
# 0.177726000 fe80::f68e:38ff:fe87:4196 ff02::1:ff87:4196 ICMPv6 86 Multicast Listener Report
# 0.178901000 fe80::225:90ff:fea4:a5ec ff02::1:ffa4:a5ec ICMPv6 86 Multicast Listener Report
# 0.183384000 fe80::da4b:de7f:406:9d78 ff02::fb ICMPv6 86 Multicast Listener Report
# 0.232181000 fe80::726d:ecff:fe02:f1 ff02::1:ff00:0 ICMPv6 86 Multicast Listener Report
# 0.253086000 fe80::3617:ebff:fe9e:3bbe ff02::1:ff9e:3bbe ICMPv6 86 Multicast Listener Report
# 0.259145000 fe80::95ab:211f:49d7:7bc6 ff02::1:3 ICMPv6 86 Multicast Listener Report
# 0.293789000 fe80::726d:ecff:fe02:70 ff02::2 ICMPv6 86 Multicast Listener Report
# 0.334396000 fe80::726d:ecff:fe02:212 ff02::1:ff02:212 ICMPv6 86 Multicast Listener Report
# ...
